# %% [markdown]
# <a href="https://www.kaggle.com/vivekramkumar/final-dl-project?scriptVersionId=83522574" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_DIR = "../input/archive/archive (1)/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# ../input/archive/archive (1)/UTKFace/61_1_20170109142408075.jpg.chip.jpg
# ../input/archive/archive (1)/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# ../input/archive/archive (1)/UTKFace/39_1_20170116174525125.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  26.0    male   asian  ../input/archive/archive (1)/UTKFace/26_0_2_20...
# 1  22.0  female   black  ../input/archive/archive (1)/UTKFace/22_1_1_20...
# 2  21.0  female  indian  ../input/archive/archive (1)/UTKFace/21_1_3_20...
# 3  28.0    male   white  ../input/archive/archive (1)/UTKFace/28_0_0_20...
# 4  17.0  female  others  ../input/archive/archive (1)/UTKFace/17_1_4_20...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='race,gender'>

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %%
p = np.random.permutation(len(df))
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# (9079, 3891, 5559, 64.0)

# %%
from tensorflow.keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout
from tensorflow.keras.optimizers import SGD
from keras.models import Model

def conv_block(inp, filters=32, bn=True, pool=True):
    _ = Conv2D(filters=filters, kernel_size=3, activation='relu')(inp)
    if bn:
        _ = BatchNormalization()(_)
    if pool:
        _ = MaxPool2D()(_)
    return _

input_layer = Input(shape=(IM_HEIGHT, IM_WIDTH, 3))
_ = conv_block(input_layer, filters=32, bn=False, pool=False)
_ = conv_block(_, filters=32*2)
_ = conv_block(_, filters=32*3)
_ = conv_block(_, filters=32*4)
_ = conv_block(_, filters=32*5)
_ = conv_block(_, filters=32*6)
bottleneck = GlobalMaxPool2D()(_)

# for age calculation
_ = Dense(units=128, activation='relu')(bottleneck)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(_)

# for race prediction
_ = Dense(units=128, activation='relu')(bottleneck)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(_)

# for gender prediction
_ = Dense(units=128, activation='relu')(bottleneck)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(_)

model = Model(inputs=input_layer, outputs=[age_output, race_output, gender_output])
model.compile(optimizer='rmsprop', 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 2., 'race_output': 1.5, 'gender_output': 1.},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# Out:
# 2021-12-27 05:41:49.479309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:49.581528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:49.582372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:49.583639: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-27 05:41:49.584704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:49.585369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:49.585992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:51.758839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:51.759666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:51.760296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 05:41:51.760865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 198, 198, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 196, 196, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 194, 194, 64) 18496       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 194, 194, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 97, 97, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 95, 95, 96)   55392       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 95, 95, 96)   384         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 47, 47, 96)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 45, 45, 128)  110720      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 45, 45, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 22, 22, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 160)  184480      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 160)  640         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 160)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 192)    276672      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 192)    768         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 192)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 192)          0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          24704       global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          24704       global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          24704       global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 1)            129         dense[0][0]
# __________________________________________________________________________________________________
# race_output (Dense)             (None, 5)            645         dense_1[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_2[0][0]
# ==================================================================================================
# Total params: 724,360
# Trainable params: 723,080
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)
callbacks = [
    ModelCheckpoint("./model_checkpoint", monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=20,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-12-27 05:42:00.057316: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 2021-12-27 05:42:03.161329: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 141/141 [==============================] - 147s 980ms/step - loss: 2.8505 - age_output_loss: 0.0674 - race_output_loss: 1.3492 - gender_output_loss: 0.6919 - age_output_mae: 0.2079 - race_output_accuracy: 0.5044 - gender_output_accuracy: 0.6770 - val_loss: 3.9378 - val_age_output_loss: 0.0536 - val_race_output_loss: 1.8263 - val_gender_output_loss: 1.0912 - val_age_output_mae: 0.2051 - val_race_output_accuracy: 0.4076 - val_gender_output_accuracy: 0.5339
# 2021-12-27 05:44:28.553207: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Epoch 2/20
# 141/141 [==============================] - 47s 331ms/step - loss: 1.8592 - age_output_loss: 0.0382 - race_output_loss: 0.9511 - gender_output_loss: 0.3562 - age_output_mae: 0.1565 - race_output_accuracy: 0.6516 - gender_output_accuracy: 0.8505 - val_loss: 2.5455 - val_age_output_loss: 0.0512 - val_race_output_loss: 1.3599 - val_gender_output_loss: 0.4033 - val_age_output_mae: 0.1955 - val_race_output_accuracy: 0.5023 - val_gender_output_accuracy: 0.8062
# Epoch 3/20
# 141/141 [==============================] - 45s 319ms/step - loss: 1.5211 - age_output_loss: 0.0311 - race_output_loss: 0.7868 - gender_output_loss: 0.2786 - age_output_mae: 0.1394 - race_output_accuracy: 0.7162 - gender_output_accuracy: 0.8910 - val_loss: 1.8954 - val_age_output_loss: 0.0308 - val_race_output_loss: 0.9805 - val_gender_output_loss: 0.3632 - val_age_output_mae: 0.1422 - val_race_output_accuracy: 0.6586 - val_gender_output_accuracy: 0.8333
# Epoch 4/20
# 141/141 [==============================] - 45s 321ms/step - loss: 1.2909 - age_output_loss: 0.0284 - race_output_loss: 0.6716 - gender_output_loss: 0.2267 - age_output_mae: 0.1327 - race_output_accuracy: 0.7624 - gender_output_accuracy: 0.9145 - val_loss: 1.5994 - val_age_output_loss: 0.0271 - val_race_output_loss: 0.8555 - val_gender_output_loss: 0.2619 - val_age_output_mae: 0.1300 - val_race_output_accuracy: 0.7031 - val_gender_output_accuracy: 0.8940
# Epoch 5/20
# 141/141 [==============================] - 46s 329ms/step - loss: 1.1164 - age_output_loss: 0.0264 - race_output_loss: 0.5812 - gender_output_loss: 0.1918 - age_output_mae: 0.1276 - race_output_accuracy: 0.7917 - gender_output_accuracy: 0.9303 - val_loss: 1.5272 - val_age_output_loss: 0.0267 - val_race_output_loss: 0.8160 - val_gender_output_loss: 0.2499 - val_age_output_mae: 0.1306 - val_race_output_accuracy: 0.7232 - val_gender_output_accuracy: 0.9023
# Epoch 6/20
# 141/141 [==============================] - 46s 326ms/step - loss: 0.9683 - age_output_loss: 0.0256 - race_output_loss: 0.4997 - gender_output_loss: 0.1676 - age_output_mae: 0.1254 - race_output_accuracy: 0.8230 - gender_output_accuracy: 0.9379 - val_loss: 1.6502 - val_age_output_loss: 0.0315 - val_race_output_loss: 0.8943 - val_gender_output_loss: 0.2457 - val_age_output_mae: 0.1341 - val_race_output_accuracy: 0.7292 - val_gender_output_accuracy: 0.9057
# Epoch 7/20
# 141/141 [==============================] - 45s 318ms/step - loss: 0.8211 - age_output_loss: 0.0249 - race_output_loss: 0.4160 - gender_output_loss: 0.1473 - age_output_mae: 0.1235 - race_output_accuracy: 0.8493 - gender_output_accuracy: 0.9469 - val_loss: 2.3359 - val_age_output_loss: 0.0369 - val_race_output_loss: 1.2177 - val_gender_output_loss: 0.4356 - val_age_output_mae: 0.1614 - val_race_output_accuracy: 0.6268 - val_gender_output_accuracy: 0.8245
# Epoch 8/20
# 141/141 [==============================] - 44s 310ms/step - loss: 0.6829 - age_output_loss: 0.0239 - race_output_loss: 0.3404 - gender_output_loss: 0.1245 - age_output_mae: 0.1203 - race_output_accuracy: 0.8775 - gender_output_accuracy: 0.9552 - val_loss: 1.9522 - val_age_output_loss: 0.0379 - val_race_output_loss: 1.0658 - val_gender_output_loss: 0.2777 - val_age_output_mae: 0.1637 - val_race_output_accuracy: 0.7159 - val_gender_output_accuracy: 0.9016
# Epoch 9/20
# 141/141 [==============================] - 43s 310ms/step - loss: 0.5679 - age_output_loss: 0.0227 - race_output_loss: 0.2754 - gender_output_loss: 0.1094 - age_output_mae: 0.1175 - race_output_accuracy: 0.9019 - gender_output_accuracy: 0.9623 - val_loss: 1.9581 - val_age_output_loss: 0.0273 - val_race_output_loss: 1.0886 - val_gender_output_loss: 0.2706 - val_age_output_mae: 0.1335 - val_race_output_accuracy: 0.7247 - val_gender_output_accuracy: 0.9065
# Epoch 10/20
# 141/141 [==============================] - 44s 314ms/step - loss: 0.4724 - age_output_loss: 0.0224 - race_output_loss: 0.2260 - gender_output_loss: 0.0885 - age_output_mae: 0.1166 - race_output_accuracy: 0.9183 - gender_output_accuracy: 0.9720 - val_loss: 1.9658 - val_age_output_loss: 0.0264 - val_race_output_loss: 1.0801 - val_gender_output_loss: 0.2929 - val_age_output_mae: 0.1263 - val_race_output_accuracy: 0.6891 - val_gender_output_accuracy: 0.9081
# Epoch 11/20
# 141/141 [==============================] - 43s 309ms/step - loss: 0.4127 - age_output_loss: 0.0217 - race_output_loss: 0.1871 - gender_output_loss: 0.0887 - age_output_mae: 0.1143 - race_output_accuracy: 0.9305 - gender_output_accuracy: 0.9680 - val_loss: 3.0909 - val_age_output_loss: 0.0279 - val_race_output_loss: 1.6830 - val_gender_output_loss: 0.5106 - val_age_output_mae: 0.1335 - val_race_output_accuracy: 0.6406 - val_gender_output_accuracy: 0.8570
# Epoch 12/20
# 141/141 [==============================] - 45s 323ms/step - loss: 0.3723 - age_output_loss: 0.0205 - race_output_loss: 0.1697 - gender_output_loss: 0.0767 - age_output_mae: 0.1106 - race_output_accuracy: 0.9385 - gender_output_accuracy: 0.9742 - val_loss: 3.2763 - val_age_output_loss: 0.0299 - val_race_output_loss: 1.9109 - val_gender_output_loss: 0.3501 - val_age_output_mae: 0.1376 - val_race_output_accuracy: 0.6849 - val_gender_output_accuracy: 0.8987
# Epoch 13/20
# 141/141 [==============================] - 46s 325ms/step - loss: 0.3306 - age_output_loss: 0.0199 - race_output_loss: 0.1473 - gender_output_loss: 0.0700 - age_output_mae: 0.1092 - race_output_accuracy: 0.9450 - gender_output_accuracy: 0.9767 - val_loss: 3.4899 - val_age_output_loss: 0.0255 - val_race_output_loss: 2.0641 - val_gender_output_loss: 0.3428 - val_age_output_mae: 0.1270 - val_race_output_accuracy: 0.6872 - val_gender_output_accuracy: 0.9049
# Epoch 14/20
# 141/141 [==============================] - 45s 322ms/step - loss: 0.2886 - age_output_loss: 0.0198 - race_output_loss: 0.1228 - gender_output_loss: 0.0648 - age_output_mae: 0.1087 - race_output_accuracy: 0.9574 - gender_output_accuracy: 0.9773 - val_loss: 2.1389 - val_age_output_loss: 0.0240 - val_race_output_loss: 1.1881 - val_gender_output_loss: 0.3087 - val_age_output_mae: 0.1202 - val_race_output_accuracy: 0.7534 - val_gender_output_accuracy: 0.9195
# Epoch 15/20
# 141/141 [==============================] - 45s 323ms/step - loss: 0.2886 - age_output_loss: 0.0191 - race_output_loss: 0.1284 - gender_output_loss: 0.0580 - age_output_mae: 0.1062 - race_output_accuracy: 0.9547 - gender_output_accuracy: 0.9811 - val_loss: 3.2760 - val_age_output_loss: 0.0302 - val_race_output_loss: 1.7773 - val_gender_output_loss: 0.5497 - val_age_output_mae: 0.1386 - val_race_output_accuracy: 0.7070 - val_gender_output_accuracy: 0.8826
# Epoch 16/20
# 141/141 [==============================] - 45s 321ms/step - loss: 0.2586 - age_output_loss: 0.0187 - race_output_loss: 0.1150 - gender_output_loss: 0.0487 - age_output_mae: 0.1049 - race_output_accuracy: 0.9629 - gender_output_accuracy: 0.9827 - val_loss: 4.5900 - val_age_output_loss: 0.0337 - val_race_output_loss: 2.7110 - val_gender_output_loss: 0.4560 - val_age_output_mae: 0.1373 - val_race_output_accuracy: 0.5945 - val_gender_output_accuracy: 0.8495
# Epoch 17/20
# 141/141 [==============================] - 46s 326ms/step - loss: 0.2485 - age_output_loss: 0.0181 - race_output_loss: 0.1075 - gender_output_loss: 0.0510 - age_output_mae: 0.1036 - race_output_accuracy: 0.9630 - gender_output_accuracy: 0.9817 - val_loss: 4.4971 - val_age_output_loss: 0.0272 - val_race_output_loss: 2.6822 - val_gender_output_loss: 0.4193 - val_age_output_mae: 0.1269 - val_race_output_accuracy: 0.6411 - val_gender_output_accuracy: 0.8974
# Epoch 18/20
# 141/141 [==============================] - 46s 325ms/step - loss: 0.2384 - age_output_loss: 0.0178 - race_output_loss: 0.1005 - gender_output_loss: 0.0519 - age_output_mae: 0.1025 - race_output_accuracy: 0.9679 - gender_output_accuracy: 0.9824 - val_loss: 4.1076 - val_age_output_loss: 0.0440 - val_race_output_loss: 2.1635 - val_gender_output_loss: 0.7742 - val_age_output_mae: 0.1547 - val_race_output_accuracy: 0.6362 - val_gender_output_accuracy: 0.8383
# Epoch 19/20
# 141/141 [==============================] - 44s 313ms/step - loss: 0.2189 - age_output_loss: 0.0172 - race_output_loss: 0.0896 - gender_output_loss: 0.0502 - age_output_mae: 0.1007 - race_output_accuracy: 0.9679 - gender_output_accuracy: 0.9828 - val_loss: 2.5932 - val_age_output_loss: 0.0315 - val_race_output_loss: 1.4102 - val_gender_output_loss: 0.4148 - val_age_output_mae: 0.1435 - val_race_output_accuracy: 0.7464 - val_gender_output_accuracy: 0.9125
# Epoch 20/20
# 141/141 [==============================] - 44s 311ms/step - loss: 0.2064 - age_output_loss: 0.0167 - race_output_loss: 0.0865 - gender_output_loss: 0.0431 - age_output_mae: 0.0995 - race_output_accuracy: 0.9717 - gender_output_accuracy: 0.9847 - val_loss: 2.7392 - val_age_output_loss: 0.0330 - val_race_output_loss: 1.4768 - val_gender_output_loss: 0.4580 - val_age_output_mae: 0.1348 - val_race_output_accuracy: 0.7013 - val_gender_output_accuracy: 0.9049

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_accuracy'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_accuracy'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_accuracy'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_accuracy'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_loss'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_loss'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# {'loss': 2.564685106277466,
#  'age_output_loss': 0.031472861766815186,
#  'race_output_loss': 1.3888499736785889,
#  'gender_output_loss': 0.4184645712375641,
#  'age_output_mae': 0.13190557062625885,
#  'race_output_accuracy': 0.7074854373931885,
#  'gender_output_accuracy': 0.9058866500854492}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83        61
#            1       0.88      0.85      0.87        27
#            2       0.80      0.67      0.73        12
#            3       0.77      0.62      0.69        16
#            4       0.21      0.42      0.28        12
#
#     accuracy                           0.73       128
#    macro avg       0.71      0.67      0.68       128
# weighted avg       0.79      0.73      0.76       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        62
#            1       0.94      0.92      0.93        66
#
#     accuracy                           0.93       128
#    macro avg       0.93      0.93      0.93       128
# weighted avg       0.93      0.93      0.93       128

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
